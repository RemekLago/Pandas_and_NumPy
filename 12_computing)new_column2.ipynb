# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./data/aapl_us_d.csv', index_col=0)
df.columns = ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
df_bool = df > 150
df1 = df[df_bool]

df1 = df[df > 150]

# %%
df_2019 = df['2019-01-01': ]
df_january_2019 = df['2019-01-01':'2019-01-31']

# %%
df_january_2019.query('Close > 40')
# Out:
#               Open    High     Low   Close     Volume
# Data
# 2019-01-30  39.572  40.274  38.842  40.052  252118098
# 2019-01-31  40.265  40.963  39.886  40.344  168077892
